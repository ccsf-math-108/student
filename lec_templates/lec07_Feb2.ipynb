# %% [markdown]
# <div style="width: 38.5%;">
#     <p><strong>City College of San Francisco</strong><p>
#     <hr>
#     <p>MATH 108 - Foundations of Data Science</p>
# </div>

# %% [markdown]
# # Lecture 07: Charts

# %% [markdown]
# Associated Textbook Sections: [7.0, 7.1](https://inferentialthinking.com/chapters/07/Visualization.html)

# %% [markdown]
# <h2>Set Up the Notebook<h2>

# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Lecture-07:-Charts" data-toc-modified-id="Lecture-07:-Charts-1">Lecture 07: Charts</a></span><ul class="toc-item"><li><span><a href="#Set-Up-the-Notebook" data-toc-modified-id="Set-Up-the-Notebook-1.1">Set Up the Notebook</a></span></li><li><span><a href="#" data-toc-modified-id="-1.2"></a></span></li><li><span><a href="#Numerical-Data" data-toc-modified-id="Numerical-Data-1.3">Numerical Data</a></span><ul class="toc-item"><li><span><a href="#Visualizing-the-Distribution-of-One-Numerical-Variable" data-toc-modified-id="Visualizing-the-Distribution-of-One-Numerical-Variable-1.3.1">Visualizing the Distribution of One Numerical Variable</a></span><ul class="toc-item"><li><span><a href="#A-Histogram" data-toc-modified-id="A-Histogram-1.3.1.1">A Histogram</a></span></li></ul></li><li><span><a href="#Plotting-Two-Numerical-Variables" data-toc-modified-id="Plotting-Two-Numerical-Variables-1.3.2">Plotting Two Numerical Variables</a></span><ul class="toc-item"><li><span><a href="#A-Line-Graph" data-toc-modified-id="A-Line-Graph-1.3.2.1">A Line Graph</a></span></li><li><span><a href="#A-Scatter-Plot" data-toc-modified-id="A-Scatter-Plot-1.3.2.2">A Scatter Plot</a></span></li></ul></li><li><span><a href="#When-to-use-a-line-vs-scatter-plot?" data-toc-modified-id="When-to-use-a-line-vs-scatter-plot?-1.3.3">When to use a line vs scatter plot?</a></span></li><li><span><a href="#Demo:-Census" data-toc-modified-id="Demo:-Census-1.3.4">Demo: Census</a></span></li><li><span><a href="#Demo:-Male-and-Female-2019-Estimates" data-toc-modified-id="Demo:-Male-and-Female-2019-Estimates-1.3.5">Demo: Male and Female 2019 Estimates</a></span></li><li><span><a href="#Demo:-Scatter-Plots" data-toc-modified-id="Demo:-Scatter-Plots-1.3.6">Demo: Scatter Plots</a></span></li></ul></li><li><span><a href="#Categorical-Data" data-toc-modified-id="Categorical-Data-1.4">Categorical Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#A-Bar-Chart" data-toc-modified-id="A-Bar-Chart-1.4.0.1">A Bar Chart</a></span></li></ul></li><li><span><a href="#Demo:-Bar-Charts" data-toc-modified-id="Demo:-Bar-Charts-1.4.1">Demo: Bar Charts</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ### Visualizing the Distribution of One Numerical Variable

# %% [markdown]
# Histograms `hist` are a standard way to visualize the distribution of one numerical variable.
#
# *Histograms will be focused on in the next lecture.*

# %% [markdown]
# #### A Histogram

# %%
actors = Table().read_table('actors.csv')
actors.show(4)
actors.hist('Total Gross', unit="Thousands of Dollars")
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Actor</th> <th>Total Gross</th> <th>Number of Movies</th> <th>Average per Movie</th> <th>#1 Movie</th> <th>Gross</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Harrison Ford    </td> <td>4871.7     </td> <td>41              </td> <td>118.8            </td> <td>Star Wars: The Force Awakens</td> <td>936.7</td>
#         </tr>
#         <tr>
#             <td>Samuel L. Jackson</td> <td>4772.8     </td> <td>69              </td> <td>69.2             </td> <td>The Avengers                </td> <td>623.4</td>
#         </tr>
#         <tr>
#             <td>Morgan Freeman   </td> <td>4468.3     </td> <td>61              </td> <td>73.3             </td> <td>The Dark Knight             </td> <td>534.9</td>
#         </tr>
#         <tr>
#             <td>Tom Hanks        </td> <td>4340.8     </td> <td>44              </td> <td>98.7             </td> <td>Toy Story 3                 </td> <td>415  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (46 rows omitted)</p>

# %% [markdown]
# ### Plotting Two Numerical Variables

# %% [markdown]
# Line graphs `plot` and Scatter plots `scatter` are standard ways to visualize the relationship of two numerical variables.

# %% [markdown]
# #### A Line Graph

# %%
movies = Table().read_table('movies_by_year.csv')
movies.show(5)
movies.where('Year', are.above(1999)).plot('Year', 'Number of Movies')
# Some extra graph formatting
plots.xticks(np.arange(2000, 2017, 2))
plots.title('Number of Movies vs. Release Year')
plots.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Total Gross</th> <th>Number of Movies</th> <th>#1 Movie</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2015</td> <td>11128.5    </td> <td>702             </td> <td>Star Wars: The Force Awakens       </td>
#         </tr>
#         <tr>
#             <td>2014</td> <td>10360.8    </td> <td>702             </td> <td>American Sniper                    </td>
#         </tr>
#         <tr>
#             <td>2013</td> <td>10923.6    </td> <td>688             </td> <td>Catching Fire                      </td>
#         </tr>
#         <tr>
#             <td>2012</td> <td>10837.4    </td> <td>667             </td> <td>The Avengers                       </td>
#         </tr>
#         <tr>
#             <td>2011</td> <td>10174.3    </td> <td>602             </td> <td>Harry Potter / Deathly Hallows (P2)</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (31 rows omitted)</p>

# %% [markdown]
# #### A Scatter Plot

# %%
actors = Table().read_table('actors.csv')
actors.scatter('Number of Movies', 'Average per Movie')
plots.title('Average Pay per Movie (Thousands of Dollars) vs. Number of Movies')
plots.show()

# %% [markdown]
# ### When to use a line vs scatter plot?

# %% [markdown]
# * Use line plots for sequential data if:
#     * ... your x-axis has an order
#     * ... sequential differences in y values are meaningful
#     * ... there's only one y-value for each x-value
# * Usually: x-axis is time or distance
# * Use scatter plots for non-sequential data --- When you’re looking for associations

# %% [markdown]
# ### Demo: Census

# %% [markdown]
# Explore the US Census data from the [Annual Estimates of the Resident Population by Single Year of Age and Sex for the United States](https://www2.census.gov/programs-surveys/popest/technical-documentation/file-layouts/2010-2020/cc-est2020-agesex.pdf).
#
# (Release date: June 2021, Updated January 2022 to include April 1, 2020 estimates)

# %%
full = Table.read_table('https://www2.census.gov/programs-surveys/popest/datasets/2010-2020/national/asrh/nc-est2020-agesex-res.csv')
full
# Out:
# SEX  | AGE  | CENSUS2010POP | ESTIMATESBASE2010 | POPESTIMATE2010 | POPESTIMATE2011 | POPESTIMATE2012 | POPESTIMATE2013 | POPESTIMATE2014 | POPESTIMATE2015 | POPESTIMATE2016 | POPESTIMATE2017 | POPESTIMATE2018 | POPESTIMATE2019 | POPESTIMATE2020
# 0    | 0    | 3944153       | 3944160           | 3951495         | 3963264         | 3926731         | 3931411         | 3954973         | 3984144         | 3963268         | 3882437         | 3826908         | 3762227         | 3735010
# 0    | 1    | 3978070       | 3978090           | 3957904         | 3966768         | 3978210         | 3943348         | 3949559         | 3973828         | 4003586         | 3981864         | 3897917         | 3842257         | 3773884
# 0    | 2    | 4096929       | 4096939           | 4090799         | 3971498         | 3980139         | 3993047         | 3960015         | 3967672         | 3992657         | 4021261         | 3996742         | 3911822         | 3853025
# 0    | 3    | 4119040       | 4119051           | 4111869         | 4102429         | 3983007         | 3992839         | 4007852         | 3976277         | 3984985         | 4009060         | 4035053         | 4009037         | 3921526
# 0    | 4    | 4063170       | 4063186           | 4077511         | 4122252         | 4112849         | 3994539         | 4006407         | 4022785         | 3992241         | 4000394         | 4021907         | 4045996         | 4017847
# 0    | 5    | 4056858       | 4056872           | 4064653         | 4087770         | 4132349         | 4123745         | 4007123         | 4020489         | 4038022         | 4007233         | 4012789         | 4032231         | 4054336
# 0    | 6    | 4066381       | 4066412           | 4073031         | 4075153         | 4097860         | 4142923         | 4135738         | 4020428         | 4034969         | 4052428         | 4019106         | 4022432         | 4040169
# 0    | 7    | 4030579       | 4030594           | 4043100         | 4083399         | 4085255         | 4108453         | 4154947         | 4148711         | 4034355         | 4048430         | 4063647         | 4027876         | 4029753
# 0    | 8    | 4046486       | 4046497           | 4025624         | 4053313         | 4093553         | 4096033         | 4120476         | 4167765         | 4162142         | 4047130         | 4059209         | 4071894         | 4034785
# 0    | 9    | 4148353       | 4148369           | 4125413         | 4035854         | 4063662         | 4104437         | 4107986         | 4133426         | 4181069         | 4175085         | 4058207         | 4067320         | 4078668
# ... (296 rows omitted)

# %% [markdown]
# Select the `SEX`, `AGE`, `CENSUS2010POP`, and `POPESTIMATE2019` columns.

# %%
census2010and2019 = full.select(0, 1, 2, 13) # could use label names instead of indices
census2010and2019.show(4)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>CENSUS2010POP</th> <th>POPESTIMATE2019</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>0   </td> <td>3944153      </td> <td>3762227        </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>1   </td> <td>3978070      </td> <td>3842257        </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>2   </td> <td>4096929      </td> <td>3911822        </td>
#         </tr>
#         <tr>
#             <td>0   </td> <td>3   </td> <td>4119040      </td> <td>4009037        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (302 rows omitted)</p>

# %% [markdown]
# Relabel the 2010 and 2019 columns.

# %%
census2010and2019 = census2010and2019.relabeled(2, '2010').relabeled(3, '2019')
census2010and2019
# Out:
# SEX  | AGE  | 2010    | 2019
# 0    | 0    | 3944153 | 3762227
# 0    | 1    | 3978070 | 3842257
# 0    | 2    | 4096929 | 3911822
# 0    | 3    | 4119040 | 4009037
# 0    | 4    | 4063170 | 4045996
# 0    | 5    | 4056858 | 4032231
# 0    | 6    | 4066381 | 4022432
# 0    | 7    | 4030579 | 4027876
# 0    | 8    | 4046486 | 4071894
# 0    | 9    | 4148353 | 4067320
# ... (296 rows omitted)

# %% [markdown]
# Sort by `AGE` in descending order.

# %%
census2010and2019 = census2010and2019.sort("AGE", descending=True)
census2010and2019
# Out:
# SEX  | AGE  | 2010      | 2019
# 0    | 999  | 308745538 | 328329953
# 1    | 999  | 151781326 | 161692336
# 2    | 999  | 156964212 | 166637617
# 0    | 100  | 53364     | 100442
# 1    | 100  | 9162      | 23531
# 2    | 100  | 44202     | 76911
# 0    | 99   | 32266     | 56774
# 1    | 99   | 6073      | 14486
# 2    | 99   | 26193     | 42288
# 0    | 98   | 45900     | 85867
# ... (296 rows omitted)

# %% [markdown]
# Remove the 999 ages and focus just on the combined data where the `SEX` value is 0. Drop the `SEX` column since there is only one value there.

# %%
everyone = census2010and2019.where("SEX", are.equal_to(0)).where("AGE", are.not_equal_to(999)).drop("SEX")
everyone
# Out:
# AGE  | 2010   | 2019
# 100  | 53364  | 100442
# 99   | 32266  | 56774
# 98   | 45900  | 85867
# 97   | 68138  | 116965
# 96   | 95223  | 157244
# 95   | 129717 | 206970
# 94   | 169449 | 263796
# 93   | 216978 | 320322
# 92   | 281389 | 393702
# 91   | 344987 | 466780
# ... (91 rows omitted)

# %% [markdown]
# Visualize the relationship between age and population size in 2010.

# %%
everyone.plot('AGE', '2010')
plots.title('US Population Size') 
plots.show()

# %% [markdown]
# Include lines for both 2010 and the estimated 2019 population sizes.

# %%
everyone.plot('AGE')
plots.title('US Population Size') 
plots.show()

# %% [markdown]
# ### Demo: Male and Female 2019 Estimates

# %% [markdown]
# Create a table with `Age`, `Males`, `Females` columns showing the population estimates in 2019 for males and females by age.

# %%
no_999 = census2010and2019.where("AGE", are.not_equal_to(999))
males = no_999.where('SEX', 1).drop('SEX')
females = no_999.where('SEX', 2).drop('SEX')
pop_2019 = Table().with_columns(
    'Age', males.column('AGE'),
    'Males', males.column('2019'),
    'Females', females.column('2019')
)
pop_2019
# Out:
# Age  | Males  | Females
# 100  | 23531  | 76911
# 99   | 14486  | 42288
# 98   | 23438  | 62429
# 97   | 32616  | 84349
# 96   | 45950  | 111294
# 95   | 61958  | 145012
# 94   | 81689  | 182107
# 93   | 103256 | 217066
# 92   | 131517 | 262185
# 91   | 160753 | 306027
# ... (91 rows omitted)

# %% [markdown]
# Visualize the distribution of of population size for both males and females.

# %%
pop_2019.plot('Age')
plots.title('2019 Population Size Estimates')
plots.show()

# %% [markdown]
# Calculate the percent female for each age

# %%
total = pop_2019.column('Males') + pop_2019.column('Females')
pct_female = pop_2019.column('Females') / total * 100
pct_female
# Out:
# array([76.57254933, 74.48479938, 72.70429851, 72.11473518, 70.77789932,
#        70.06426052, 69.03326813, 67.76493653, 66.59478489, 65.56129226,
#        64.36264302, 63.42875214, 62.43469375, 61.50555207, 60.61994754,
#        59.77448788, 59.12037315, 58.2875019 , 57.64539476, 57.03744511,
#        56.3748233 , 56.17047137, 55.82854715, 55.26819948, 54.83251151,
#        54.58073446, 54.25448772, 53.9509406 , 53.51022877, 53.44223716,
#        53.40722561, 53.27081102, 53.26468499, 53.03484444, 52.92230043,
#        52.76149769, 52.44314993, 52.31329221, 52.09723728, 51.88456258,
#        51.72648051, 51.46437873, 51.53410868, 51.37238838, 51.2696241 ,
#        51.13627062, 50.89138769, 50.81894266, 50.80649435, 50.63449931,
#        50.56911629, 50.44489454, 50.61870656, 50.57544456, 50.64261911,
#        50.48253869, 50.27570341, 50.36508359, 50.37327215, 50.20977831,
#        50.1409379 , 49.89892133, 50.08019625, 49.99258886, 49.88801204,
#        49.7823678 , 49.57328862, 49.39653681, 49.34690992, 49.33570713,
#        49.27161137, 49.23311185, 49.115004  , 48.84567382, 48.68996749,
#        48.76311842, 48.77220901, 48.84655675, 48.95129043, 48.89699809,
#        48.8800806 , 48.85555766, 48.94499775, 48.9917086 , 49.00723665,
#        48.99213593, 48.95682562, 48.91588355, 48.91848904, 48.96313718,
#        48.98425388, 48.96592842, 48.85910586, 48.89552211, 48.89701056,
#        48.83289177, 48.88153622, 48.89917454, 48.87032181, 48.90344399,
#        48.93979018])

# %% [markdown]
# Round the values to 3 decimal places so that it's easier to read.

# %%
pct_female.round(3)
# Out:
# array([76.573, 74.485, 72.704, 72.115, 70.778, 70.064, 69.033, 67.765,
#        66.595, 65.561, 64.363, 63.429, 62.435, 61.506, 60.62 , 59.774,
#        59.12 , 58.288, 57.645, 57.037, 56.375, 56.17 , 55.829, 55.268,
#        54.833, 54.581, 54.254, 53.951, 53.51 , 53.442, 53.407, 53.271,
#        53.265, 53.035, 52.922, 52.761, 52.443, 52.313, 52.097, 51.885,
#        51.726, 51.464, 51.534, 51.372, 51.27 , 51.136, 50.891, 50.819,
#        50.806, 50.634, 50.569, 50.445, 50.619, 50.575, 50.643, 50.483,
#        50.276, 50.365, 50.373, 50.21 , 50.141, 49.899, 50.08 , 49.993,
#        49.888, 49.782, 49.573, 49.397, 49.347, 49.336, 49.272, 49.233,
#        49.115, 48.846, 48.69 , 48.763, 48.772, 48.847, 48.951, 48.897,
#        48.88 , 48.856, 48.945, 48.992, 49.007, 48.992, 48.957, 48.916,
#        48.918, 48.963, 48.984, 48.966, 48.859, 48.896, 48.897, 48.833,
#        48.882, 48.899, 48.87 , 48.903, 48.94 ])

# %% [markdown]
# Add female percent to our table

# %%
pop_2019 = pop_2019.with_column('Percent female', pct_female)
pop_2019
# Out:
# Age  | Males  | Females | Percent female
# 100  | 23531  | 76911   | 76.5725
# 99   | 14486  | 42288   | 74.4848
# 98   | 23438  | 62429   | 72.7043
# 97   | 32616  | 84349   | 72.1147
# 96   | 45950  | 111294  | 70.7779
# 95   | 61958  | 145012  | 70.0643
# 94   | 81689  | 182107  | 69.0333
# 93   | 103256 | 217066  | 67.7649
# 92   | 131517 | 262185  | 66.5948
# 91   | 160753 | 306027  | 65.5613
# ... (91 rows omitted)

# %% [markdown]
# Visualize the relationship between age and the percent of the population that is female.

# %%
pop_2019.plot('Age', 'Percent female')
plots.title('Female Population Percentage over Age')
plots.show()

# %% [markdown]
# Be careful of being visually mislead by the y-axis.

# %%
pop_2019.plot('Age', 'Percent female')
plots.ylim(0, 100);
plots.title('Female Population Percentage over Age')
plots.show()

# %% [markdown]
# ### Demo: Scatter Plots

# %%
actors = Table.read_table('actors.csv')
actors
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie                     | Gross
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens | 936.7
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers                 | 623.4
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight              | 534.9
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3                  | 415
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers                 | 623.4
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2                      | 441.2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds            | 234.3
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest             | 423.3
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight              | 534.9
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers                 | 623.4
# ... (40 rows omitted)

# %% [markdown]
# Visualize the relationship between the number of movies and the total gross for each actor in the dataset.

# %%
actors.scatter('Number of Movies', 'Total Gross')
plots.title('Total Gross (Thousands of Dollars) vs. Number of Movies')
plots.show()

# %% [markdown]
# Visualize the relationship between the number of movies and the average pay per movie for each actor in the dataset.

# %%
actors.scatter('Number of Movies', 'Average per Movie')
plots.title('Average per Movie (Thousands of Dollars) vs. Number of Movies')
plots.show()

# %% [markdown]
# Identify the outlier in the dataset.

# %%
actors.where('Average per Movie', are.above(400)).column('Actor').item(0)
# Out:
# 'Anthony Daniels'

# %%
typical_actors = actors.where('Average per Movie', are.below(400))
typical_actors.scatter('Number of Movies', 'Average per Movie')
plots.title('Average per Movie (Thousands of Dollars) vs. Number of Movies')
plots.show()

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# * (Horizontal) Bar charts `barh` are the standard way to visualize the distribution of a single categorical variable.
# * Pie charts are generally discouraged because most people have a difficult time visually interpreting angles.

# %% [markdown]
# #### A Bar Chart

# %%
cones = Table().read_table('cones.csv')
cones.show(3)
flavor_count = cones.group('Flavor').relabeled('count', 'Count')
flavor_count.show(3)
flavor_count.barh('Flavor')
plots.title('Distribution of Ice Cream Flavors')
plots.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Flavor</th> <th>Color</th> <th>Price</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>strawberry</td> <td>pink       </td> <td>3.55 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>light brown</td> <td>4.75 </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>dark brown </td> <td>5.25 </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (3 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Flavor</th> <th>Count</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>bubblegum </td> <td>1    </td>
#         </tr>
#         <tr>
#             <td>chocolate </td> <td>3    </td>
#         </tr>
#         <tr>
#             <td>strawberry</td> <td>2    </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Demo: Bar Charts

# %% [markdown]
# Load the dataset showing the highest grossing movies as of 2017

# %%
top_movies = Table.read_table('top_movies_2017.csv')
top_movies
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973
# Snow White and the Seven Dwarves | Disney          | 184925486 | 969010000        | 1937
# ... (190 rows omitted)

# %% [markdown]
# Reduce the table to the top top 10 movies based on gross (adjusted) values.

# %%
top10_adjusted = top_movies.take(np.arange(10))
top10_adjusted
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973
# Snow White and the Seven Dwarves | Disney          | 184925486 | 969010000        | 1937

# %% [markdown]
# Convert to the gross (adjusted) values to millions of dollars for readability.

# %%
millions = np.round(top10_adjusted.column('Gross (Adjusted)') / 1000000, 3)
top10_adjusted = top10_adjusted.with_column('Millions', millions)
top10_adjusted
# Out:
# Title                            | Studio          | Gross     | Gross (Adjusted) | Year | Millions
# Gone with the Wind               | MGM             | 198676459 | 1796176700       | 1939 | 1796.18
# Star Wars                        | Fox             | 460998007 | 1583483200       | 1977 | 1583.48
# The Sound of Music               | Fox             | 158671368 | 1266072700       | 1965 | 1266.07
# E.T.: The Extra-Terrestrial      | Universal       | 435110554 | 1261085000       | 1982 | 1261.09
# Titanic                          | Paramount       | 658672302 | 1204368000       | 1997 | 1204.37
# The Ten Commandments             | Paramount       | 65500000  | 1164590000       | 1956 | 1164.59
# Jaws                             | Universal       | 260000000 | 1138620700       | 1975 | 1138.62
# Doctor Zhivago                   | MGM             | 111721910 | 1103564200       | 1965 | 1103.56
# The Exorcist                     | Warner Brothers | 232906145 | 983226600        | 1973 | 983.227
# Snow White and the Seven Dwarves | Disney          | 184925486 | 969010000        | 1937 | 969.01

# %% [markdown]
# Notice that a line plot doesn't really show a relationship between the year and the gross adjusted values.

# %%
top10_adjusted.plot('Year', 'Millions')
plots.title("The relationship between Year and Gross (Adjusted)")
plots.show()

# %% [markdown]
# Visualize the gross adjusted values for each of the top 10 grossing (adjusted) movies.

# %%
top10_adjusted.barh('Title', 'Millions')
plots.title("The Top 10 Grossing Movies (in Millions of Dollars)")
plots.show()

# %% [markdown]
# <footer>
#     <hr>
#     <p>Adopted from UC Berkeley DATA 8 course materials.</p>
#     <p>This content is offered under a <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">CC Attribution Non-Commercial Share Alike</a> license.</p>
# </footer>
